# %% [markdown]
# ### Przypisana karta graficzna

# %%
# !nvidia-smi
# Out:
# Tue Jun 18 13:37:07 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W /  70W |   5707MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Import bibliotek

# %%
import numpy as np
import matplotlib.pyplot as plt
# !pip install imgaug
# !pip install scikit-learn
from imgaug import augmenters as iaa
from imgaug import parameters as iap
import random
import pandas as pd

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, Dropout, MaxPooling2D, Lambda

# !pip install livelossplot
from livelossplot import PlotLossesKeras
from livelossplot.keras import PlotLossesCallback

# %% [markdown]
# ### Wczytanie tensorów X i y

# %%
X = np.load('X.npy')
y = np.load('y.npy')

# %%
print(X.shape, y.shape)

# %% [markdown]
# ### Zdefiniowanie parametrów augmentacji

# %%
def augment(img, steering_angle):
  ##flip
  if random.random() > 0.5:
    img = img[:, ::-1, :]
    steering_angle = -steering_angle
  
  ##blur
  blurer = iaa.GaussianBlur(iap.Uniform(0.1, 2))
  img = blurer.augment_image(img)
  
  contrast = iaa.GammaContrast((0.5,2.0))
  img = contrast.augment_image(img)
  
  ##channel shuffle
  sh = iaa.ChannelShuffle(p=0.4)
  img = sh.augment_image(img)
  
  #snow = iaa.Snowflakes(density=(0.03,0.075))
  #img = snow.augment_image(img)
  
  ##fog
  fog = iaa.Fog()
  img = fog.augment_image(img)
  
  #translate
  tx = random.randint(-20,20)
  translater = iaa.Affine(translate_px={"x":tx}, mode = "edge")
  steering_angle += tx*0.025
  
  img = translater.augment_image(img)
    
  return img, steering_angle
  
plt.imshow(X[0])
print(y[0])
plt.show();
  
img, angle = augment(X[0], y[0])
plt.imshow(img)
print(angle)
plt.show();
# Out:
# 0.0
# -0.375

# %% [markdown]
# ### Podział X i y na zbiór treningowy i walidacyjny

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)

# %% [markdown]
# ### Augmentacja danych

# %%
Xgen=[]
ygen=[]


for i in range(X_train.shape[0]):
  img,angle = augment(X[i],y[i])
  Xgen.append(img)
  ygen.append(angle)
  
  
Xgen = np.array(Xgen)
ygen = np.array(ygen)
print(Xgen.shape, ygen.shape)

# %% [markdown]
# ### Porównanie y przed i po augmentacji

# %%
plt.figure(figsize=(10,5))
plt.hist(y_train, 50, facecolor='green');
plt.hist(ygen, 50, facecolor='red');
plt.xlabel('Steering angle');
plt.ylabel('Number of observations');
plt.legend(['Data before augmentation','Data after modification']);
plt.show()

# %% [markdown]
# ### Budowa architektury CNN - wariant 2

# %%
# MODEL WŁASNY 02
# 3xConv2D (3x3)+ 3xMaxPool

def myModel(input_shape):
  model = Sequential([
      Lambda(lambda x: (x-128.0)/255.0, input_shape = input_shape, 
             name='normalize'),
          
      Conv2D(32,(3,3), activation = 'relu'),
      MaxPooling2D(pool_size=(2,2),strides=(2,2)),
      Dropout(rate=0.25),
      
      Conv2D(64,(3,3), activation = 'relu'), 
      MaxPooling2D(pool_size=(2,2),strides=(2,2)), 
      Dropout(rate=0.25),
      
      Conv2D(128,(3,3), activation = 'relu'), 
      MaxPooling2D(pool_size=(2,2),strides=(2,2)), 
      Dropout(rate=0.25),
           
      Flatten(),
      
      Dense(1024, activation = 'relu'),
      Dropout(rate=0.5),
      Dense(1)
  ])
  return model
model = myModel(X[0].shape)

# %% [markdown]
# ### Kompilacja modelu

# %%
#kompilacja modelu
model.compile(optimizer='adam', 
              loss='mean_squared_error')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalize (Lambda)           (None, 35, 80, 3)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 33, 78, 32)        896
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 39, 32)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 16, 39, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 37, 64)        18496
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 7, 18, 64)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 7, 18, 64)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 16, 128)        73856
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 2, 8, 128)         0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 2, 8, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,192,449
# Trainable params: 2,192,449
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Trenowanie modelu

# %%
batch_size = 512
epochs =40

history = model.fit(Xgen, ygen,
         batch_size=batch_size,
         epochs=epochs,
         validation_data=(X_val, y_val),
         callbacks=[PlotLossesCallback()],
         verbose=2)
# Out:
# Mean squared error (cost function):
# training   (min:    0.062, max:    0.265, cur:    0.062)
# validation (min:    0.052, max:    0.141, cur:    0.062)

# %% [markdown]
# ### Predykcja danych i porównanie y i y_pred

# %%
y_pred = model.predict(X)

plt.figure()
plt.plot(y,'g', y_pred,'r')
plt.xlabel('Image number');
plt.ylabel('Steering angle');
plt.legend(['y','y_pred']);

plt.show();

# %% [markdown]
# ### Zapis modelu

# %%
model.save('cnn_model_wlasny_02_b512_e40_relu.h5')
